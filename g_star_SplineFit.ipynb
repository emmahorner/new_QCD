# %%
import numpy as np
import spline_gstar as sg

# %%
T, g_star, g_star_s = np.loadtxt("SMgstar.dat", usecols = (0,1,2), unpack = True)

# %%
sg.save_spline_params(T, g_star, g_star_s)

# %%
sg.plot_spline_fit("Relativistic_Degrees_of_Freedom.npz")
