# %%
import AnalysisTools
import matplotlib.pyplot as plt

# %%
data180 = AnalysisTools.MSNDM_model('.', '180')
data360 = AnalysisTools.MSNDM_model('.', '360')
data540 = AnalysisTools.MSNDM_model('.', '540')
data720 = AnalysisTools.MSNDM_model('.', '720')

# %%
def save_and_plot_mixscatter(data, name, dpi=1200):
    data.make_mixscatter(save_fig=True, save_fn=name)

data180 = AnalysisTools.MSNDM_model('.', '180')
data360 = AnalysisTools.MSNDM_model('.', '360')
data540 = AnalysisTools.MSNDM_model('.', '540')
data720 = AnalysisTools.MSNDM_model('.', '720')

save_and_plot_mixscatter(data180, "180-mixscatter", dpi=1200)
save_and_plot_mixscatter(data360, "360-mixscatter", dpi=1200)
save_and_plot_mixscatter(data540, "540-mixscatter", dpi=1200)
save_and_plot_mixscatter(data720, "720-mixscatter", dpi=1200)


def save_and_plot_contour(data, name, dpi=1200):
    data.make_contourplot(save_fig=True, save_fn=name)
    
data180 = AnalysisTools.MSNDM_model('.', '180')
data360 = AnalysisTools.MSNDM_model('.', '360')
data540 = AnalysisTools.MSNDM_model('.', '540')
data720 = AnalysisTools.MSNDM_model('.', '720')
save_and_plot_contour(data180, "180-contour", dpi=1200)
save_and_plot_contour(data360, "360-contour", dpi=1200)
save_and_plot_contour(data540, "540-contour", dpi=1200)
save_and_plot_contour(data720, "720-contour", dpi=1200)
# Out:
# Image saved 180-mixscatter.png
# Image saved 360-mixscatter.png
# Image saved 540-mixscatter.png
# Image saved 720-mixscatter.png
# Image saved 180-contour.png
# Image saved 360-contour.png
# Image saved 540-contour.png
# Image saved 720-contour.png
